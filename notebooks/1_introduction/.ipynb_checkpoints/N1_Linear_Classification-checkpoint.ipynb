# %% [markdown]
# This notebook can be run on mybinder: [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/git/https%3A%2F%2Fgricad-gitlab.univ-grenoble-alpes.fr%2Fchatelaf%2Fconference-ia/2c6cb77f696206f100c5352e89d8c2ec80ef700a?filepath=notebooks/1_introduction/N1_Linear_Classification.ipynb)

# %%
# Import modules
# %matplotlib inline
import matplotlib
import scipy as sp
import matplotlib.pyplot as plt

# %%
# Select random seed
random_state = 0

# %% [markdown]
# We use scikit-learn to generate a toy 2D data set

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_features=2, n_redundant=0, n_informative=2, n_samples=150,
                          random_state=random_state, n_clusters_per_class=1)
y[y==0]=-1
plt.scatter(X[:,0], X[:,1], c=y)
plt.grid("on")

# %% [markdown]
# Then, a linear model is used to learn the classification function.

# %%
from sklearn import linear_model
model = linear_model.RidgeClassifier()
model.fit(X,y)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='auto',
#         tol=0.001)

# %%
# Plot the decision functions
XX, YY = sp.meshgrid(sp.linspace(X[:,0].min(), X[:,0].max(),200),
                     sp.linspace(X[:,1].min(), X[:,1].max(),200))
XY = sp.vstack([XX.flatten(), YY.flatten()]).T
yp = model.predict(XY)
plt.contour(XX,YY,yp.reshape(XX.shape),[0])
plt.scatter(X[:,0], X[:,1], c=y)
plt.grid("true")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
print(-model.coef_[0][0]/model.coef_[0][1])
print(model.intercept_)
# Out:
# -0.5567792434998338
# [-0.4201191]
